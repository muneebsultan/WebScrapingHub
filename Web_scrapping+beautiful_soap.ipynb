# %% [markdown]
# Web scraping using beautiful soup

# %%
# %pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading soupsieve-2.6-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.12.3 soupsieve-2.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup
import urllib
from urllib import request

import urllib.request as ur

# %%
## For scraping specific HTML tags along with titles and meta description
urlinput = input("Enter url :")

def getTags(tag):
  s = ur.urlopen(urlinput)
  soup = BeautifulSoup(s.read())
  return soup.findAll(tag)

def titleandmetaTags():
    s = ur.urlopen(urlinput)
    soup = BeautifulSoup(s.read())
    title = soup.title.string
    print ('Website Title is :', title)
    meta_description = soup.find_all('meta')
    for tag in meta_description:
        if 'name' in tag.attrs.keys() and tag.attrs['name'].strip().lower() in ['description', 'keywords']:
            #print ('NAME    :',tag.attrs['name'].lower())
            print ('CONTENT :',tag.attrs['content'])

if __name__ == '__main__':
  titleandmetaTags()
  tags = getTags('h1')
  for tag in tags:
     print(tag) # display tags 
     print(tag.contents) # display contents of the tags
# Out:
# Website Title is : Ben & Jerry’s says parent Unilever silenced it over Gaza stance - World - DAWN.COM
# CONTENT : Unilever rejects claims made by B&Js social mission board, says "will defend our case very strongly.”
# CONTENT : Unilever rejects claims made by B&Js social mission board, says "will defend our case very strongly.”
# CONTENT : Gaza invasion

# %%
## extracting specific tags, all heading tags from h1-h6 along with titles and meta description
urlinput = input("Enter url :")
print(" This is the website link that you entered", urlinput)

def getTags(tag):
  s = ur.urlopen(urlinput)
  soup = BeautifulSoup(s.read())
  return soup.findAll(tag)

def titleandmetaTags():
    s = ur.urlopen(urlinput)
    soup = BeautifulSoup(s.read())
    title = soup.title.string
    print ('Title :', title)
    meta_description = soup.find_all('meta')
    for tag in meta_description:
        if 'name' in tag.attrs.keys() and tag.attrs['name'].strip().lower() in ['description', 'keywords']:
            print ('CONTENT :',tag.attrs['content'])

if __name__ == '__main__':
  titleandmetaTags()
  tags = getTags('h1')
  for tag in tags:
     print(tag) # display tags 
     print(tag.contents) # display contents of the tags
# Out:
#  This is the website link that you entered https://www.dawn.com
# Title : Home - DAWN.COM
# CONTENT : Pakistan’s most trusted outlet for the breaking, latest and top news across the country and the world.

# %%
#For extracting ALT tags (Image Alter tags)
import urllib.request as ur

url_input = input("Enter url :")
print("The website link that you entered is:", url_input)

def alt_tag():
  url =  ur.urlopen(url_input)
  htmlSource = url.read()
  url.close()
  soup = BeautifulSoup(htmlSource)
  print('\n The alt tag along with the text in the web page')
  print(soup.find_all('img',alt= True))
  

if __name__ == '__main__':
  alt_tag()
# Out:
# The website link that you entered is: https://www.dawn.com
#
#  The alt tag along with the text in the web page
# [<img alt="DAWN.COM Logo" class="w-44" src="https://www.dawn.com/_img/logo.png"/>, <img alt="FO terms media reports on Pak-China joint security ‘motivated by agenda to create confusion’" src="https://i.dawn.com/medium/2024/11/141553113eb95fe.jpg?r=155344" title="FO terms media reports on Pak-China joint security ‘motivated by agenda to create confusion’"/>, <img alt="Israel warfare methods in Gaza ‘consistent with genocide’: UN committee" src="https://i.dawn.com/medium/2024/11/141600268e76398.jpg?r=160045" title="Israel warfare methods in Gaza ‘consistent with genocide’: UN committee"/>, <img alt="On its first day, SC’s constitutional bench seeks reports from provinces on actions against pollution" src="https://i.dawn.com/medium/2024/11/141654310a6f6f2.png?r=165628" title="On its first day, SC’s constitutional bench seeks reports from provinces on actions against pollution"/>, <img alt="PSX crosses new all-time high of 94,000" src="https://i.dawn.com/medium/2024/11/141707280a16b18.png?r=171707" title="PSX crosses new all-time high of 94,000"/>, <img alt="Scuffle breaks out between PTI and PPP supporters at Karachi’s Gizri" src="https://i.dawn.com/medium/2024/11/14150119a261f8b.jpg?r=152519" title="Scuffle breaks out between PTI and PPP supporters at Karachi’s Gizri"/>, <img alt="Ben &amp; Jerry’s says parent Unilever silenced it over Gaza stance" src="https://i.dawn.com/medium/2024/11/141628362e5b08f.jpg?r=163000" title="Ben &amp; Jerry’s says parent Unilever silenced it over Gaza stance"/>, <img alt="Iran activist kills himself after demanding release of prisoners" src="https://i.dawn.com/medium/2024/11/14171050a545408.jpg?r=174645" title="Iran activist kills himself after demanding release of prisoners"/>, <img alt="India’s toxic smog hides Taj Mahal, delays flights" src="https://i.dawn.com/medium/2024/11/141353060851f66.jpg?r=141341" title="India’s toxic smog hides Taj Mahal, delays flights"/>, <img alt="Lahore tops global pollution chart again as govt tries to tackle crisis" src="https://i.dawn.com/medium/2024/11/1413220078b3cac.jpg?r=134955" title="Lahore tops global pollution chart again as govt tries to tackle crisis"/>, <img alt="Suspect wanted by India arrested on gun charges in Canada: report" src="https://i.dawn.com/medium/2024/11/141245286ff0fd0.jpg?r=131742" title="Suspect wanted by India arrested on gun charges in Canada: report"/>, <img alt="What’s Next For Ukraine? Will Trump Bring Peace by Easing Russia Sanctions?" class="lazyload" data-src="https://i.ytimg.com/vi/455pEga3Mj4/mqdefault.jpg" src="..." title="What’s Next For Ukraine? Will Trump Bring Peace by Easing Russia Sanctions?"/>, <img alt="Top News: Netanyahu Discusses Iran Threat With Trump In Recent Calls" class="lazyload" data-src="https://i.ytimg.com/vi/cgWlfbQ6vBg/mqdefault.jpg" src="..." title="Top News: Netanyahu Discusses Iran Threat With Trump In Recent Calls"/>, <img alt="Let’s Talk About How Your Body Changes During Pregnancy" class="lazyload" data-src="https://i.ytimg.com/vi/WgOKd_AIAuA/mqdefault.jpg" src="..." title="Let’s Talk About How Your Body Changes During Pregnancy"/>, <img alt="What Are The Concerns?" class="lazyload" data-src="https://i.ytimg.com/vi/UPQVT9p5QBg/mqdefault.jpg" src="..." title="What Are The Concerns?"/>, <img alt="World Leaders Condemn Suicide Bombing at Quetta Railway Station" class="lazyload" data-src="https://i.ytimg.com/vi/PBtQsByWc4g/mqdefault.jpg" src="..." title="World Leaders Condemn Suicide Bombing at Quetta Railway Station"/>, <img alt="Top News: Quetta Blast; Israel Pounds Gaza; Threats to Black Americans" class="lazyload" data-src="https://i.ytimg.com/vi/fDuWnfors1g/mqdefault.jpg" src="..." title="Top News: Quetta Blast; Israel Pounds Gaza; Threats to Black Americans"/>, <img alt="Amsterdam Violence: How It Started?" class="lazyload" data-src="https://i.ytimg.com/vi/qgQlAHinH28/mqdefault.jpg" src="..." title="Amsterdam Violence: How It Started?"/>, <img alt="Lahore’s dangerous smog: where disease and death ...
# </img>, <img alt="China Daily Logo" class="mb-4" pinger-seen="true" src="https://i.dawn.com/primary/2021/01/600147aa0fd21.png"/>, <img alt="Aan Logo" src="https://i.dawn.com/large/2023/05/101806417ad96bf.png" style="width:100px">
# </img>, <img alt="DAWN.COM Logo" class="w-20" src="https://www.dawn.com/_img/logo-white.png"/>, <img alt="Whatsapp" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2024/02/080925032506f93.png"/>, <img alt="Twitter" class="align-baseline mt-1 mr-2" src="https://i.dawn.com/large/2024/02/16125537351049d.png" style="height:17px"/>, <img alt="Facebook" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c42cf5e8.png" width="20"/>, <img alt="Instagram" class="align-baseline mt-1 mr-2" height="20" src="https://i.dawn.com/thumbnail/2019/02/5c611c430f9b2.png" width="20"/>, <img alt="Apple" class="align-baseline mt-1 mr-2" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42d5669.png" width="20"/>, <img alt="Android" class="align-baseline mt-1 mr-2" height="34" src="https://i.dawn.com/thumbnail/2019/02/5c611c42ce48d.png" width="20"/>, <img alt="Huwaei App Gallery" class="align-baseline mt-1" height="30" src="https://i.dawn.com/thumbnail/2021/05/60a360ab86d68.png" width="100"/>]

# %%
# %pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp312-cp312-win_amd64.whl (102 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.8.30 charset-normalizer-3.4.0 idna-3.10 requests-2.32.3 urllib3-2.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter
from string import punctuation

r = requests.get("https://www.dawn.com")
soup = BeautifulSoup(r.content)

text_paragraph = (''.join(s.findAll(text=True))for s in soup.findAll('p'))
count_paragraph = Counter((x.rstrip(punctuation).lower() for y in text_paragraph for x in y.split()))

text_div = (''.join(s.findAll(text=True))for s in soup.findAll('div'))
count_div = Counter((x.rstrip(punctuation).lower() for y in text_div for x in y.split()))

total = count_div + count_paragraph
list_most_common_words = total.most_common()
# Out:
# C:\Users\fdhfd\AppData\Local\Temp\ipykernel_18812\3580084934.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text_paragraph = (''.join(s.findAll(text=True))for s in soup.findAll('p'))
# C:\Users\fdhfd\AppData\Local\Temp\ipykernel_18812\3580084934.py:15: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text_div = (''.join(s.findAll(text=True))for s in soup.findAll('div'))

# %%
print(len(list_most_common_words))
# Out:
# 1086

# %%
list_most_common_words
# Out:
# [('', 9229),
#  ('box/title', 880),
#  ('article', 748),
#  ('/article', 748),
#  ('box/image', 689),
#  ('the', 480),
#  ('to', 437),
#  ('box/excerpt', 344),
#  ('2024', 299),
#  ('in', 299),
#  ('of', 271),
#  ('box/date', 255),
#  ('nov', 255),
#  ('bold-playfairdisplay-text:3.5-sm:text:3', 242),
#  ('box/byline', 230),
#  ('a', 194),
#  ('for', 154),
#  ('published', 146),
#  ('and', 140),
#  ('as', 121),
#  ('box/label', 119),
#  ('14', 116),
#  ('updated', 109),
#  ('is', 108),
#  ('on', 102),
#  ('with', 101),
#  ('pakistan', 93),
#  ('bold-playfairdisplay-pb:0-pb:sm:2-text:3.5', 90),
#  ('world', 88),
#  ('it', 86),
#  ('from', 78),
#  ('security', 76),
#  ('out', 73),
#  ('bold-center-targetblank', 70),
#  ('gaza', 67),
#  ('an', 63),
#  ('title-bold-playfairdisplay-text:5', 60),
#  ('text:3', 60),
#  ('business', 58),
#  ('at', 57),
#  ('by', 56),
#  ('new', 56),
#  ('title-bold-playfairdisplay-pb:1-text:4-sm:text:3.5', 54),
#  ('win', 53),
#  ('after', 52),
#  ('10', 49),
#  ('govt', 48),
#  ('bold-leading:tight-mb:2', 48),
#  ('has', 47),
#  ('their', 47),
#  ('13', 47),
#  ('israel', 46),
#  ('high', 46),
#  ('images', 45),
#  ('china’s', 45),
#  ('ali', 45),
#  ('bold-playfairdisplay-pb:2-text:4-sm:text:3', 45),
#  ('says', 44),
#  ('12', 43),
#  ('trump', 42),
#  ('that', 42),
#  ('bold-playfairdisplay-pb:2-text:3.5-sm:text:3', 42),
#  ('his', 41),
#  ('but', 40),
#  ('bold-playfairdisplay-text:4', 40),
#  ('smog', 39),
#  ('1', 39),
#  ('over', 38),
#  ('are', 38),
#  ('australia', 38),
#  ('about', 37),
#  ('if', 37),
#  ('aamir', 37),
#  ('time', 37),
#  ('women’s', 37),
#  ('sports', 37),
#  ('opinion', 36),
#  ('reports', 36),
#  ('pollution', 36),
#  ('global', 36),
#  ('india', 36),
#  ('years', 36),
#  ('cop29', 36),
#  ('07:08am', 36),
#  ('concerns', 35),
#  ('case', 35),
#  ('sport', 34),
#  ('googletag.cmd.push(function', 34),
#  ('victory', 34),
#  ('news', 33),
#  ('power', 33),
#  ('2', 32),
#  ('3', 32),
#  ('energy', 32),
#  ('bold-playfairdisplay-pb:1-text:3.75-sm:text:3.5', 32),
#  ('up', 31),
#  ('breathe', 30),
#  ('popular', 30),
#  ('bold-playfairdisplay-text:4-sm:text:3.25-center.5-sm:pt:1-pb:1-sm:pb:0',
#   30),
#  ('not', 29),
#  ('dawn', 29),
#  ('may', 29),
#  ('khan’s', 29),
#  ('solar', 29),
#  ('agreement', 29),
#  ('fintech', 29),
#  ('be', 29),
#  ('lunar', 29),
#  ('advert:start', 28),
#  ('advert:end', 28),
#  ('editorial', 28),
#  ('pakistan’s', 28),
#  ('digital', 28),
#  ('india’s', 27),
#  ('how', 27),
#  ('ties', 27),
#  ('whoopi', 27),
#  ('goldberg', 27),
#  ('launches', 27),
#  ('channel', 27),
#  ('exclusively', 27),
#  ('dedicated', 27),
#  ('take', 27),
#  ('—', 27),
#  ('will', 26),
#  ('seeks', 26),
#  ('against', 26),
#  ('mission', 26),
#  ('having', 26),
#  ('top', 26),
#  ('08:34pm', 26),
#  ('minister', 26),
#  ('staff', 26),
#  ('climate', 26),
#  ('khan', 25),
#  ('death', 25),
#  ('last', 25),
#  ('states', 25),
#  ('refusal', 25),
#  ('4', 25),
#  ('5', 25),
#  ('apocalypse', 25),
#  ('live', 24),
#  ('iran', 24),
#  ('bold-playfairdisplay-pb:1-italic-text:3.5', 24),
#  ('hussain', 24),
#  ('trade', 24),
#  ('un', 23),
#  ('threat', 23),
#  ('recent', 23),
#  ('have', 23),
#  ('ago', 23),
#  ('possible', 23),
#  ('nav', 22),
#  ('beijing', 22),
#  ('finding', 22),
#  ('financial', 22),
#  ('punjab', 22),
#  ('all', 22),
#  ('dot', 21),
#  ('title-anchor', 21),
#  ('kills', 21),
#  ('unilever', 21),
#  ('wanted', 21),
#  ('arrested', 21),
#  ('odi', 21),
#  ('meeting', 21),
#  ('finance', 21),
#  ('find', 21),
#  ('ahmed', 21),
#  ('end', 20),
#  ('was', 20),
#  ('leaders', 20),
#  ('quetta', 20),
#  ('violence', 20),
#  ('imf', 20),
#  ('buried', 20),
#  ('forgotten', 20),
#  ('history', 20),
#  ('rafia', 20),
#  ('zakaria', 20),
#  ('trump’s', 20),
#  ('almost', 20),
#  ('family', 20),
#  ('tech', 19),
#  ('fo', 19),
#  ('terms', 19),
#  ('first', 19),
#  ('more', 19),
#  ('addressed', 19),
#  ('satisfactorily', 19),
#  ('affect', 19),
#  ('bilateral', 19),
#  ('why', 19),
#  ('hindu', 19),
#  ('retirement', 19),
#  ('acting', 19),
#  ('greatly', 19),
#  ('exaggerated', 19),
#  ('exploration', 19),
#  ('again', 18),
#  ('lahore’s', 18),
#  ('dangerous', 18),
#  ('where', 18),
#  ('disease', 18),
#  ('stalk', 18),
#  ('china', 18),
#  ('hania', 18),
#  ('doesn’t', 18),
#  ('cover', 18),
#  ('blemishes', 18),
#  ('onscreen', 18),
#  ('unless', 18),
#  ('she', 18),
#  ('really', 18),
#  ('sponsored', 18),
#  ('24', 18),
#  ('hours', 18),
#  ('newspaper', 18),
#  ('policy', 18),
#  ('november', 17),
#  ('prism', 17),
#  ('bombing', 17),
#  ('issue', 17),
#  ('very', 17),
#  ('during', 17),
#  ('body', 17),
#  ('kamran', 17),
#  ('kamal', 17),
#  ('ceo', 17),
#  ('hubco', 17),
#  ('speaks', 17),
#  ('company’s', 17),
#  ('venture', 17),
#  ('into', 17),
#  ('cars', 17),
#  ('plan', 17),
#  ('change', 17),
#  ('pta', 17),
#  ('vpn', 17),
#  ('search', 16),
#  ('sensible', 16),
#  ('baloch', 16),
#  ('kalbe', 16),
#  ('sri', 16),
#  ('can', 16),
#  ('other', 16),
#  ('apec', 16),
#  ('economies', 16),
#  ('hits', 16),
#  ('record', 16),
#  ('jan-oct', 16),
#  ('culture', 16),
#  ('wizardry', 16),
#  ('brings', 16),
#  ('cultural', 16),
#  ('heritage', 16),
#  ('life', 16),
#  ('discovering', 16),
#  ('peruvian’s', 16),
#  ('journey', 16),
#  ('aurora', 15),
#  ('cooperation', 15),
#  ('its', 15),
#  ('actions', 15),
#  ('our', 15),
#  ('vote', 15),
#  ('read', 15),
#  ('stories', 15),
#  ('strengthens', 15),
#  ('collaboration', 15),
#  ('distributed', 15),
#  ('market', 15),
#  ('across', 15),
#  ('europe', 15),
#  ('united', 15),
#  ('asia-pacific', 15),
#  ('advancing', 15),
#  ('shift', 15),
#  ('clean', 15),
#  ('renowned', 15),
#  ('hair', 15),
#  ('care', 15),
#  ('brand', 15),
#  ('aims', 15),
#  ('empower', 15),
#  ('contestants', 15),
#  ('showcase', 15),
#  ('best', 15),
#  ('selves', 15),
#  ('confidence', 15),
#  ('historic', 15),
#  ('sector', 15),
#  ('hakeem’s', 15),
#  ('pioneering', 15),
#  ('islamic', 15),
#  ('nano-financing', 15),
#  ('solution', 15),
#  ('garners', 15),
#  ('recognition', 15),
#  ('call', 15),
#  ('young', 15),
#  ('dawn.com', 14),
#  ('chinese', 14),
#  ('warfare', 14),
#  ('methods', 14),
#  ('‘consistent', 14),
#  ('genocide’', 14),
#  ('committee', 14),
#  ('ben', 14),
#  ('jerry’s', 14),
#  ('parent', 14),
#  ('silenced', 14),
#  ('stance', 14),
#  ('psx', 14),
#  ('crosses', 14),
#  ('all-time', 14),
#  ('94,000', 14),
#  ('activist', 14),
#  ('himself', 14),
#  ('demanding', 14),
#  ('release', 14),
#  ('prisoners', 14),
#  ('toxic', 14),
#  ('hides', 14),
#  ('taj', 14),
#  ('mahal', 14),
#  ('delays', 14),
#  ('flights', 14),
#  ('suspect', 14),
#  ('gun', 14),
#  ('charges', 14),
#  ('canada', 14),
#  ('report', 14),
#  ('partners', 14),
#  ('sustainability', 14),
#  ('ja', 14),
#  ('osw', 14),
#  ('sign', 14),
#  ('gw', 14),
#  ('distribution', 14),
#  ('tresemmé', 14),
#  ('empowers', 14),
#  ('aspiring', 14),
#  ('entrepreneurs', 14),
#  ('styling', 14),
#  ('partner', 14),
#  ('shark', 14),
#  ('tank', 14),
#  ('walee', 14),
#  ('services’', 14),
#  ('hakeem', 14),
#  ('clinches', 14),
#  ('emerging', 14),
#  ('award', 14),
#  ('sff', 14),
#  ('media', 13),
#  ('pakistan-china', 13),
#  ('say', 13),
#  ('bench', 13),
#  ('thrashed', 13),
#  ('eight-wicket', 13),
#  ('bringing', 13),
#  ('series', 13),
#  ('22', 13),
#  ('unwilling', 13),
#  ('accept', 13),
#  ('reasons', 13),
#  ('visit', 13),
#  ('education', 13),
#  ('"there', 13),
#  ('sense', 13),
#  ('educational', 13),
#  ('loss', 13),
#  ('decision', 13),
#  ('taken', 13),
#  ('compulsion', 13),
#  ('08:00pm', 13),
#  ('04:28am', 13),
#  ('holds', 13),
#  ('introductory', 13),
#  ('pledges', 13),
#  ('gas', 13),
#  ('supply', 13),
#  ('captive', 13),
#  ('plants', 13),
#  ('jan', 13),
#  ('07:15am', 13),
#  ('oic-arab', 13),
#  ('league', 13),
#  ('resolution', 13),
#  ('does', 13),
#  ('go', 13),
#  ('beyond', 13),
#  ('usual', 13),
#  ('condemnation', 13),
#  ("trump's", 13),
#  ('far', 13),
#  ('convincing', 13),
#  ('than', 13),
#  ('8', 13),
#  ('testament', 13),
#  ('democrats', 13),
#  ('decrepitude', 13),
#  ('maps', 13),
#  ('pickaxes', 13),
#  ('now', 13),
#  ('discover', 13),
#  ('ancient', 13),
#  ('relics', 13),
#  ('distance', 13),
#  ('we', 13),
#  ('still', 13),
#  ('individuals', 13),
#  ('organisations', 13),
#  ('investing', 13),
#  ('future', 13),
#  ('second', 13),
#  ('reminds', 13),
#  ('humanity', 13),
#  ('manmade', 13),
#  ('hasn’t', 13),
#  ('receded', 13),
#  ('home', 12),
#  ('latest', 12),
#  ('siege', 12),
#  ('magazines', 12),
#  ('videos', 12),
#  ('archive', 12),
#  ('flood', 12),
#  ('donations', 12),
#  ('line', 12),
#  ('politicians', 12),
#  ('cricket', 12),
#  ('fraternity', 12),
#  ('congratulate', 12),
#  ('green', 12),
#  ('shirts', 12),
#  ('pcb', 12),
#  ('asks', 12),
#  ('icc', 12),
#  ('explain', 12),
#  ('champions', 12),
#  ('trophy', 12),
#  ('orders', 12),
#  ('closure', 12),
#  ('schools', 12),
#  ('province', 12),
#  ('tackles', 12),
#  ('hazardous', 12),
#  ('air', 12),
#  ('quality', 12),
#  ('cartoon', 12),
#  ('update', 12),
#  ('revenue', 12),
#  ('system’s', 12),
#  ('overhaul', 12),
#  ('zahid', 12),
#  ('summit', 12),
#  ('nowhere', 12),
#  ('mahir', 12),
#  ('trumped', 12),
#  ('nadeem', 12),
#  ('jawad', 12),
#  ('inspiration', 12),
#  ('jawed', 12),
#  ('naqvi', 12),
#  ('won’t', 12),
#  ('see', 12),
#  ('what’s', 10),
#  ('next', 10),
#  ('ukraine', 10),
#  ('bring', 10),
#  ('peace', 10),
#  ('easing', 10),
#  ('russia', 10),
#  ('sanctions', 10),
#  ('netanyahu', 10),
#  ('discusses', 10),
#  ('calls', 10),
#  ('let’s', 10),
#  ('talk', 10),
#  ('your', 10),
#  ('changes', 10),
#  ('pregnancy', 10),
#  ('what', 10),
#  ('condemn', 10),
#  ('suicide', 10),
#  ('railway', 10),
#  ('station', 10),
#  ('blast', 10),
#  ('pounds', 10),
#  ('threats', 10),
#  ('black', 10),
#  ('americans', 10),
#  ('amsterdam', 10),
#  ('started', 10),
#  ('beijing’s', 10),
#  ('fears', 10),
#  ('fills', 10),
#  ('key', 10),
#  ('posts', 10),
#  ('hawks', 10),
#  ('aren’t', 10),
#  ('reshaping', 10),
#  ('legal', 10),
#  ('framework', 10),
#  ('drastically', 10),
#  ('tilt', 10),
#  ('executive’s', 10),
#  ('favour', 10),
#  ('pakistani', 10),
#  ('authorities', 10),
#  ('performative', 10),
#  ('approach', 10),
#  ('solving', 10),
#  ('terrorism', 10),
#  ('running', 10),
#  ('stop', 10),
#  ('melting', 10),
#  ('kush', 10),
#  ('himalaya', 10),
#  ('muslim', 10),
#  ('even', 10),
#  ('coming', 10),
#  ('together', 10),
#  ('denounce', 10),
#  ('genocidal', 10),
#  ('achievement', 10),
#  ("googletag.display('div-gpt-ad-1683363673257-0", 10),
#  ('oped', 10),
#  ('writers', 10),
#  ('superstar', 10),
#  ('confirmed', 10),
#  ('he', 10),
#  ('quit', 10),
#  ('few', 10),
#  ('emphasis', 10),
#  ('talked', 10),
#  ('him', 10),
#  ('network', 10),
#  ('available', 10),
#  ('65', 10),
#  ('countries', 10),
#  ('including', 10),
#  ('gather', 10),
#  ('ismail', 10),
#  ('among', 10),
#  ('millions', 10),
#  ('whose', 10),
#  ('plight', 10),
#  ('serves', 10),
#  ('stark', 10),
#  ('reminder', 10),
#  ('human', 10),
#  ('cost', 10),
#  ('empire', 10),
#  ('unravels', 10),
#  ('"short-fingered', 10),
#  ('vulgarian', 10),
#  ('reclaims', 10),
#  ('throne', 10),
#  ('objectives', 10),
#  ('include', 10),
#  ('exploring', 10),
#  ('surface', 10),
#  ('conducting', 10),
#  ('experiments', 10),
#  ('testing', 10),
#  ('technologies', 10),
#  ('planetary', 10),
#  ('"as', 10),
#  ('proactive', 10),
#  ('measure', 10),
#  ('companies', 10),
#  ('freelancers', 10),
#  ('encouraged', 10),
#  ('register', 10),
#  ('vpns', 10),
#  ('ensure', 10),
#  ('smooth', 10),
#  ('operations', 10),
#  ('despite', 10),
#  ('ample', 10),
#  ('data', 10),
#  ('understanding', 10),
#  ('patterns', 10),
#  ('failed', 10),
#  ('decisions', 10),
#  ('combat', 10),
#  ('given', 10),
#  ('us’s', 10),
#  ('veto', 10),
#  ('council', 10),
#  ('politically', 10),
#  ('difficult', 10),
#  ('legally', 10),
#  ('singer', 10),
#  ('sara', 10),
#  ('raza', 10),
#  ('assertion', 10),
#  ('paucity', 10),
#  ('singing', 10),
#  ('talent', 10),
#  ('country', 10),
#  ('caused', 10),
#  ('quite', 10),
#  ('stir', 10),
#  ('showbiz', 10),
#  ('circles', 10),
#  ('clocking', 10),
#  ('92', 10),
#  ('minutes', 10),
#  ('cut', 10),
#  ('long', 10),
#  ('uninvolving', 10),
#  ('tiring', 10),
#  ('piece', 10),
#  ('pointlessness', 10),
#  ('10:58pm', 9),
#  ('10:40pm', 9),
#  ('10:21pm', 9),
#  ('timeline', 9),
#  ('<div', 9),
#  ("class='relative", 9),
#  ('overflow-hidden', 9),
#  ('mb-4', 9),
#  ('<a', 9),
#  ('href="/live/gaza-invasion', 9),
#  ('class="text-red-custom', 9),
#  ('uppercase', 9),
#  ('font-arial', 9),
#  ('align-middle', 9),
#  ('text-2.75', 9),
#  ('mb-3', 9),
#  ('flex', 9),
#  ('items-center', 9),
#  ('<span', 9),
#  ('class="w-2', 9),
#  ('h-2', 9),
#  ('rounded-full', 9),
#  ('bg-red-200', 9),
#  ('mx-1', 9),
#  ('fx-pulse"></span', 9),
#  ('ghaza', 9),
#  ('invasion', 9),
#  ('</a', 9),
#  ('<iframe', 9),
#  ('class="newskit-custom-iframe', 9),
#  ('src="//www.dawn.com/widgets/timeline/gaza-invasion', 9),
#  ('width="100', 9),
#  ('height="250', 9),
#  ('frameborder="0', 9),
#  ('scrolling="no', 9),
#  ('onload="var', 9),
#  ('self', 9),
#  ('this', 9),
#  ("window.addeventlistener('message", 9),
#  ('function(event', 9),
#  ('(event.data.id', 9),
#  ('self.src', 9),
#  ('livevent.data.height', 9),
#  ("'number", 9),
#  ('self.style.height', 9),
#  ('event.data.height', 9),
#  ("'px", 9),
#  ('});"></iframe', 9),
#  ('</div', 9),
#  ('must', 9),
#  ('div-gpt-ad-1683363673257-0', 9),
#  ('rulers', 9),
#  ('through', 9),
#  ('relegating', 9),
#  ('judiciary', 9),
#  ('status', 9),
#  ('attached', 9),
#  ('department', 9),
#  ('shahab', 9),
#  ('usto', 9),
#  ("china's", 9),
#  ("aren't", 9),
#  ('ct', 9),
#  ('should', 9),
#  ('pursued', 9),
#  ('instead', 9),
#  ('foreign', 9),
#  ('forces', 9),
#  ('here', 9),
#  ('kush-himalayan', 9),
#  ('region', 9),
#  ('big', 9),
#  ('trouble', 9),
#  ('study', 9),
#  ('unveiled', 9),
#  ('ongoing', 9),
#  ('reveals', 9),
#  ('government', 9),
#  ('approved', 9),
#  ('expensive', 9),
#  ('fbr', 9),
#  ('hope', 9),
#  ('tackling', 9),
#  ('deep-seated', 9),
#  ('inefficiencies', 9),
#  ('01:37pm', 9),
#  ('01:14pm', 9),
#  ('melts', 9),
#  ('around', 9),
#  ('them', 9),
#  ('refugees', 9),
#  ('hunza', 9),
#  ('pin', 9),
#  ('hopes', 9),
#  ('faisal', 9),
#  ('farooq', 9),
#  ('01:48pm', 9),
#  ('donald', 9),
#  ('supremacy', 9),
#  ('asad', 9),
#  ('rahim', 9),
#  ('08', 9),
#  ('03:05pm', 9),
#  ('suparco', 9),
#  ('joins', 9),
#  ('amin', 9),
#  ('08:59am', 9),
#  ('introduces', 9),
#  ('registration', 9),
#  ('portal', 9),
#  ('users', 9),
#  ('umaid', 9),
#  ('09:09pm', 9),
#  ('environment', 9),
#  ('or', 9),
#  ('sheheryar', 9),
#  ('suspend', 9),
#  ('aidan', 9),
#  ('hehir', 9),
#  ('grapevine', 9),
#  ('pyt', 9),
#  ('streaming', 9),
#  ('farheen', 9),
#  ('jawaid', 9),
#  ('english', 8),
#  ('imran', 8),
#  ('gabol', 8),
#  ('zahoor', 8),
#  ('atika', 8),
#  ('rehman', 8),
#  ('waqar', 8),
#  ('most', 8),
#  ('bold-playfairdisplay-pb:1-center-text:3.75-sm:text:3.5', 8),
#  ('judiciary’s', 8),
#  ('debacle', 8),
#  ('protecting', 8),
#  ('investments', 8),
#  ('khurram', 8),
#  ('husain', 8),
#  ('f.s', 8),
#  ('aijazuddin', 8),
#  ('optimising', 8),
#  ('gulmina', 8),
#  ('bilal', 8),
#  ('ahmad', 8),
#  ('steep', 8),
#  ('price', 8),
#  ('high-cost', 8),
#  ('sole', 8),
#  ('pia', 8),
#  ('bid', 8),
#  ('formally', 8),
#  ('rejected', 8),
#  ('sent', 8),
#  ('back', 8),
#  ('cabinet', 8),
#  ('stocks', 8),
#  ('recover', 8),
#  ('131', 8),
#  ('points', 8),
#  ('mixed', 8),
#  ('mini-budget', 8),
#  ('unlikely', 8),
#  ('satisfied', 8),
#  ('tax', 8),
#  ('steps', 8),
#  ('draft', 8),
#  ('ship', 8),
#  ('owners', 8),
#  ('bank', 8),
#  ('help', 8),
#  ('realise', 8),
#  ('$60bn', 8),
#  ('export', 8),
#  ('potential', 8),
#  ('seek', 8),
#  ('replicate', 8),
#  ('show', 8),
#  ('t20s', 8),
#  ('aussies', 8),
#  ('alcaraz', 8),
#  ('beats', 8),
#  ('rublev', 8),
#  ('open', 8),
#  ('atp', 8),
#  ('finals', 8),
#  ('account', 8),
#  ('ghulam', 8),
#  ('fatima', 8),
#  ('leads', 8),
#  ('invincibles', 8),
#  ('psb', 8),
#  ('pff', 8),
#  ('nc’s', 8),
#  ('congress', 8),
#  ('‘illegal’', 8),
#  ('lanka', 8),
#  ('‘a’', 8),
#  ('solid', 8),
#  ('start', 8),
#  ('shaheens', 8),
#  ('earn', 8),
#  ('lead', 8),
#  ('lankans', 8),
#  ('issues', 8),
#  ('welfare', 8),
#  ('economic', 8),
#  ('reforms', 8),
#  ('stake', 8),
#  ('04:19pm', 8),
#  ('zofeen', 8),
#  ('t', 8),
#  ('ebrahim', 8),
#  ('11:50am', 8),
#  ('signals', 8),
#  ('further', 8),
#  ('curbs', 8),
#  ('11:22am', 8),
#  ('mohammed', 8),
#  ('hanif', 8),
#  ('11', 8),
#  ('08:56am', 8),
#  ('livewire', 8),
#  ('stage', 8),
#  ('peerzada', 8),
#  ('salman', 8),
#  ('12:20pm', 8),
#  ('herald', 7),
#  ('cityfm89', 7),
#  ('advertise', 7),
#  ('classifieds', 7),
#  ('obituaries', 7),
#  ('blog', 7),
#  ('elections', 7),
#  ('scrutiny', 7),
#  ('concludes', 7),
#  ('nomination', 7),
#  ('papers', 7),
#  ('48', 7),
#  ('senate', 7),
#  ('seats', 7),
#  ('ecp', 7),
#  ('notifies', 7),
#  ('mahmood', 7),
#  ('pti-p', 7),
#  ('chairman', 7),
#  ('“we', 7),
#  ('would', 7),
#  ('allow', 7),
#  ('any', 7),
#  ('effort', 7),
#  ('derail', 7),
#  ('strategic', 7),
#  ('partnership,”', 7),
#  ('spokesperson', 7),
#  ('asserts', 7),
#  ('related', 7),
#  ('msf', 7),
#  ('denounces', 7),
#  ('israel’s', 7),
#  ('"outrageous', 7),
#  ('denial', 7),
#  ('medical', 7),
#  ('evacuations', 7),
#  ('israeli', 7),
#  ("gaza's", 7),
#  ('beit', 7),
#  ('lahiya', 7),
#  ('six-judge', 7),
#  ('adjourns', 7),
#  ('hearing', 7),
#  ('2007', 7),
#  ('weeks', 7),
#  ('justice', 7),
#  ('mandokhail', 7),
#  ('notes', 7),
#  ('environmental', 7),
#  ('countrywide', 7),
#  ('rejects', 7),
#  ('claims', 7),
#  ('made', 7),
#  ('b&js', 7),
#  ('social', 7),
#  ('board', 7),
#  ('"will', 7),
#  ('defend', 7),
#  ('strongly.”', 7),
#  ('analyst', 7),
#  ('attributes', 7),
#  ('800-points', 7),
#  ('rally', 7),
#  ('macro-indicators', 7),
#  ('appearing', 7),
#  ('"stable', 7),
#  ('warns', 7),
#  ('"sharp', 7),
#  ('corrections', 7),
#  ('incident', 7),
#  ('took', 7),
#  ('place', 7),
#  ('when', 7),
#  ('mayor', 7),
#  ('murtaza', 7),
#  ('wahab', 7),
#  ('addressing', 7),
#  ('casting', 7),
#  ('local', 7),
#  ('by-elections', 7),
#  ('multan', 7),
#  ('police', 7),
#  ('deploys', 7),
#  ('457', 7),
#  ('officers', 7),
#  ('assist', 7),
#  ('carrying', 7),
#  ('“anti-smog', 7),
#  ('initiatives”', 7),
#  ('many', 7),
#  ('opposition', 7),
#  ('spectrum', 7),
#  ('express', 7),
#  ('grief', 7),
#  ('"responsible', 7),
#  ('officials', 7),
#  ('blamed', 7),
#  ('combined', 7),
#  ('humidity', 7),
#  ('becalmed', 7),
#  ('winds', 7),
#  ('drop', 7),
#  ('temperature', 7),
#  ('gill', 7),
#  ('month', 7),
#  ('described', 7),
#  ('been', 7),
#  ('“very', 7),
#  ('close”', 7),
#  ('slain', 7),
#  ('sikh', 7),
#  ('separatist', 7),
#  ('hardeep', 7),
#  ('singh', 7),
#  ('nijjar', 7),
#  ("googletag.display('div-gpt-ad-1683363763562-0", 7),
#  ('america', 7),
#  ('economy', 7),
#  ('lowering', 7),
#  ('crop', 7),
#  ('production', 7),
#  ('costs', 7),
#  ('overworked', 7),
#  ('underpaid', 7),
#  ('–', 7),
#  ('healers', 7),
#  ('d’land', 7),
#  ('iqbal’s', 7),
#  ('vision', 7),
#  ('voices', 7),
#  ('mailbox', 7),
#  ('sponsorships', 7),
#  ('pave', 7),
#  ('way', 7),
#  ('sporting', 7),
#  ('success', 7),
#  ('student’s', 7),
#  ('urgent', 7),
#  ('action', 7),
#  ("googletag.display('div-gpt-ad-1683363860950-0", 7),
#  ('☰', 6),
#  ('x', 6),
#  ('title-bold-playfairdisplay-pb:1-text:5', 6),
#  ('pak-china', 6),
#  ('joint', 6),
#  ('‘motivated', 6),
#  ('agenda', 6),
#  ('create', 6),
#  ('confusion’', 6),
#  ('05:17pm', 6),
#  ('attempt', 6),
#  ('undermine', 6),
#  ('yield', 6),
#  ...]

# %%
#Extraction of all URLs from a website without duplication
import re
import requests
from bs4 import BeautifulSoup

all_links = set()

for i in range(7):
   r = requests.get(("https://techoid.co/?page={}").format(i))
   soup = BeautifulSoup(r.content , "html.parser")
   for link in soup.find_all("a",href=re.compile('/')):
            link = (link.get('href'))
            if link not in all_links:
              print(link)
            all_links.add(link)
# Out:
# https://www.facebook.com/Techoid.co/
# https://x.com/Techoid_co
# https://www.linkedin.com/company/techoid
# https://www.instagram.com/techoidco/
# https://api.whatsapp.com/send?phone=923110206987
